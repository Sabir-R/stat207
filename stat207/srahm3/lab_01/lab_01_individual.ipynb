# %% [markdown]
# # STAT 207 Lab Assignment 1 - Individual Part - [25 total points]
#
# ## Python with Jupyter Notebooks

# %% [markdown]
# Due: Tuesday, August 30, 11:59pm CST
# <hr>

# %% [markdown]
# ## <u>Purpose</u>:
# The purpose of this individual lab assignment is to verify that you have successfully installed and set up all of the necessary data science applications that we will be using in this class. We will also practice some basic dataframe summarization functions as well as visualize of a single **categorical** variable.
#
# ## <u>Case Study</u>: Learning More about Billionaires
#
# In this case study we will explore the list of all the world's billionaires from 2021 https://www.forbes.com/real-time-billionaires/#49c85f6e3d78. We will use this dataset to answer the following research questions.
#
# ### Research Questions
#
# 1. What types of industries are these 2021 billionaires most likely to make their income from?
# 2. What countries are these 2021 billionaires most likely to live in?
#
#
#
# <hr>

# %% [markdown]
# ## <u>Instructions</u>:
#
# ### Part 1. [8 pts for successfully submitting this notebook to Github]
#
# Make sure you have the following packages installed for Python on your computer: pandas, matplotlib.pyplot, seaborn.
# To install them, launch a **command line window** and issue commands of the form:
#
#     conda install *package_name_here*
#
# To check if they are installed issue the command:
#
#     conda list
#
# and look through the list to make sure the packages you need are there. When done, return to this notebook.

# %% [markdown]
# ### Part 2. Imports [4 points for getting the code below to run]
#
# After ensuring that the packages listed above are installed on your computer import them here in the notebook by running the following commands. You should be able to do this by clicking anywhere inside the cell to select it and then hitting the 'Run' button in the menu at the top of this page.

# %%
import pandas as pd                    # imports pandas and calls the imported version 'pd'
import matplotlib.pyplot as plt        # imports the package and calls it 'plt'
import seaborn as sns                  # imports the seaborn package with the imported name 'sns'
sns.set()                              # sets the default plotting style

# %% [markdown]
# ### Part 3. Basic Display of the Dataset
#
# **a)** [3 points] You should have a file "Billionaire.csv" in the same folder as this notebook. Read the file into a pandas data frame. You may call it "df" or whatever you like. As illustrated in the class notes, use the **.head()** function to display the first several lines of the data frame.

# %%
df = pd.read_csv('Billionaire.csv')
df.head()
# Out:
#                        Name NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %% [markdown]
# **b)** [1 point] Use **.shape** to determine how many observations (rows) there are.

# %%
df.shape
# Out:
# (2755, 7)

# %% [markdown]
# ### Part 4. Industry Source of Income of Billionaires
#
# The data contains several variables describing each of the billionaires in the dataframe. The seventh column, 'Industry', lists the industry that the billionaire derives their income from in 2021.
#
# **a)** [3 points] Using python commands in the cell below, determine how many billionaires there are that get their income from each type of industry.
#
# **For full credit, you must do this in one line of code**.

# %%
df_industry = df.groupby("Industry").agg("count").reset_index()
df_industry
# Out:
#                       Industry  Name  NetWorth  Country  Source  Rank  Age
# 0                   Automotive    68        68       68      68    68   67
# 1   Construction & Engineering    44        44       44      44    44   43
# 2                  Diversified   188       188      188     188   188  180
# 3                       Energy   100       100      100     100   100   99
# 4             Fashion & Retail   273       273      273     273   273  268
# 5        Finance & Investments   371       371      371     371   371  365
# 6              Food & Beverage   219       219      219     219   219  204
# 7           Gambling & Casinos    25        25       25      25    25   25
# 8                   Healthcare   221       221      221     221   221  213
# 9                    Logistics    35        35       35      35    35   35
# 10               Manufacturing   331       331      331     331   331  317
# 11       Media & Entertainment    95        95       95      95    95   92
# 12             Metals & Mining    74        74       74      74    74   73
# 13                 Real Estate   215       215      215     215   215  211
# 14                     Service    75        75       75      75    75   73
# 15                      Sports    24        24       24      24    24   24
# 16                  Technology   365       365      365     365   365  355
# 17                     Telecom    32        32       32      32    32   32

# %% [markdown]
# ### Part 5. Residence of Billionaires
#
# The third column, 'Country' lists where the billionaire lived in 2021.
#
# #### a) Counts [1 points]
#
#  Using python commands in the cell below, determine how many billionaires there are from each country in this dataset.
#
# **For full credit, you must do this in one line of code**.

# %%
df_country = df.groupby("Country").agg("count").reset_index()
df_country
# Out:
#            Country  Name  NetWorth  Source  Rank  Age  Industry
# 0          Algeria     1         1       1     1    1         1
# 1        Argentina     5         5       5     5    4         5
# 2        Australia    44        44      44    44   43        44
# 3          Austria    12        12      12    12   12        12
# 4          Belgium     3         3       3     3    3         3
# ..             ...   ...       ...     ...   ...  ...       ...
# 65  United Kingdom    56        56      56    56   54        56
# 66   United States   724       724     724   724  720       724
# 67       Venezuela     1         1       1     1    1         1
# 68         Vietnam     6         6       6     6    6         6
# 69        Zimbabwe     1         1       1     1    1         1
#
# [70 rows x 7 columns]

# %% [markdown]
# #### b.) Basic Barplot [3 points]
# Using python commands in the cell below, make a barplot that shows the counts of how many billionaires there are from each country.
#
# Be sure to include:
# * a title
# * an appropriate label for your x-axis
# * an appropriate label for your y-axis.

# %%
sns.barplot(x=df_country["Country"], y=df_country["Name"])

plt.title("Number of Billionares per Country")
plt.xlabel("Countries")
plt.ylabel("Number of Billionares")
plt.show()

# %% [markdown]
# #### c.) Plot Labels Rotation [1 points]
# Most likely you were unable to to see the labels on the x-axis in your plot above. Run the same code that you have in 5b below, but add the following line of code just above the **plt.show()** line.
#
# ```plt.xticks(rotation = 90)```
#
# This will rotate your x-axis labels by 90 degrees.

# %%
sns.barplot(x=df_country["Country"], y=df_country["Name"])

plt.title("Number of Billionares per Country")
plt.xlabel("Countries")
plt.ylabel("Number of Billionares")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### d) Figure Resizing [1 points]
# Most likely your plot above is still quite difficult to read. Let's try resizing the plot.
#
#
# Run the same code that you have in 5c below, but add the following line of code *right before you start using any plotting related functions*.
#
# ```plt.figure(figsize=(15,10))```
#
# The **plt.figure()** function tells Matplotlib to create a "blank canvas" for a new figure that you can build upon and add things to in the subsequent lines of code below it (before the *plt.show()* is run). The **figsize=(15,10)** parameter that we set within this function will create a figure with a width of 15" and a height of 10".

# %%
plt.figure(figsize=(15,10))

sns.barplot(x=df_country["Country"], y=df_country["Name"])

plt.title("Number of Billionares per Country")
plt.xlabel("Countries")
plt.ylabel("Number of Billionares")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Important Tip when Coding in Jupyter Notebooks
#
# Remember to keep all your cells and hit the save icon above periodically to checkpoint (save) your results on your local computer. Once you are satisified with your results restart the kernel and run all. **Make sure nothing has changed**. Checkpoint and exit. Follow the git submit instructions to submit your notebook.
